# %%
# !uv add numpy
# Out:
# Resolved 35 packages in 1.39s
# ⠹ Preparing packages... (0/1)
# ⠹ Preparing packages... (0/1)-------------------     0 B/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 13.84 KiB/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 19.37 KiB/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 30.44 KiB/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 41.51 KiB/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 47.04 KiB/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 52.57 KiB/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 58.10 KiB/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 63.63 KiB/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 64.00 KiB/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 68.15 KiB/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 73.68 KiB/15.87 MiB
# ⠹ Preparing packages... (0/1)------------------- 79.21 KiB/15.87 MiB
# ...

# %%
import numpy
arr = numpy.array([1, 2, 3, 4, 5])
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np
arr = np.array(["a", "b", "c", "d", "e"])
print(arr)
print(type(arr))
# Out:
# ['a' 'b' 'c' 'd' 'e']
# <class 'numpy.ndarray'>

# %% [markdown]
# Checking numpy version

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.4
